# %%
import os
import sys
sys.path.append(os.getcwd())
sys.path.append(os.getcwd() + '/../src')

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
import logging
import re
from concurrent.futures import ThreadPoolExecutor
import multiprocessing
from recurrent.parameters import AllLogs
import jax
import jax.numpy as jnp
jax.config.update("jax_platform_name", "cpu")

# %%
# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.StreamHandler(sys.stdout),
        logging.FileHandler('grid_analysis.log')
    ]
)
logger = logging.getLogger(__name__)

# Set multiprocessing start method to 'spawn' to avoid JAX fork issues
multiprocessing.set_start_method("spawn", force=True)

# %%
# Configuration
download_dir = "/scratch/downloaded_artifacts"
results_dir = "/scratch/results"
group_name = "mlr_search-1_aa9c06652fb34624bebe972b1fe7292f"
max_process_workers = 10
success_threshold = 0.95

# %%
os.makedirs(results_dir, exist_ok=True)

# %%
def sanitize_folder_name(name):
    return re.sub(r'[^\w\-]', '_', str(name))

# %%
# Function to process a single run's logs
def process_run(run_result):
    run_id = run_result["run_id"]
    artifact_dir = run_result["artifact_dir"]
    config = run_result["config"]
    
    if run_result["status"] != "success" or not artifact_dir or not config:
        logger.warning(f"Skipping run {run_id}: download failed or no config")
        return {
            "run_id": run_id,
            "status": "skipped",
            "data": None
        }
    
    log_file = os.path.join(artifact_dir, "logs.pkl")
    if not os.path.exists(log_file):
        logger.error(f"Logs file not found for run {run_id}")
        return {
            "run_id": run_id,
            "status": "no_log_file",
            "data": None
        }
    
    try:
        with open(log_file, "rb") as f:
            logs = pickle.load(f)
        
        if not isinstance(logs, AllLogs):
            logger.error(f"Logs for run {run_id} is not an AllLogs instance")
            return {
                "run_id": run_id,
                "status": "invalid_logs",
                "data": None
            }
        
        is_success = not np.any(logs.hyperparameters == 1e-4)
        final_test_loss = float(logs.test_loss[-1]) if is_success and logs.test_loss is not None else None
        
        logger.info(f"Processed run {run_id}: success={is_success}, final_test_loss={final_test_loss}")
        
        return {
            "run_id": run_id,
            "status": "success",
            "data": {
                "config": config,
                "is_success": is_success,
                "final_test_loss": final_test_loss,
                "ts": tuple(config.get("ts", ())),
                "inner_optimizer": config.get("inner_optimizer", "unknown"),
                "inner_learner": config.get("inner_learner", "unknown")
            }
        }
    except Exception as e:
        logger.error(f"Error processing logs for run {run_id}: {str(e)}")
        return {
            "run_id": run_id,
            "status": f"error: {str(e)}",
            "data": None
        }

# %%
def create_grid_plot(runs_data, optimizer, learner, group_name):
    # Filter runs by optimizer and learner
    filtered_runs = [
        run for run in runs_data
        if run["config"].get("inner_optimizer", "unknown") == optimizer
        and run["config"].get("inner_learner", "unknown") == learner
    ]
    
    if not filtered_runs:
        logger.warning(f"No runs found for inner_optimizer={optimizer}, inner_learner={learner}")
        return
    
    # Organize data by outer and inner learning rates
    lr_grid = defaultdict(list)
    for run in filtered_runs:
        outer_lr = run["config"].get("outer_learning_rate")
        inner_lr = run["config"].get("inner_learning_rate")
        lr_grid[(outer_lr, inner_lr)].append(run)
    
    # Compute success fractions and collect test losses
    outer_lrs = sorted(set(run["config"].get("outer_learning_rate") for run in filtered_runs))
    inner_lrs = sorted(set(run["config"].get("inner_learning_rate") for run in filtered_runs))
    ts_list = sorted(set(run["ts"] for run in filtered_runs), key=lambda x: x[0])
    
    if not outer_lrs or not inner_lrs:
        logger.warning(f"No valid learning rates for inner_optimizer={optimizer}, inner_learner={learner}")
        return
    
    # Create grid plot
    fig, axes = plt.subplots(len(inner_lrs), len(outer_lrs), figsize=(len(outer_lrs) * 4, len(inner_lrs) * 4), squeeze=False)
    
    for i, inner_lr in enumerate(inner_lrs):
        for j, outer_lr in enumerate(outer_lrs):
            ax = axes[i, j]
            runs = lr_grid.get((outer_lr, inner_lr), [])
            
            # Calculate success fraction
            total_runs = len(runs)
            successful_runs = len([run for run in runs if run["is_success"]])
            success_fraction = successful_runs / total_runs if total_runs > 0 else 0
            
            if success_fraction >= success_threshold and total_runs > 0:
                # Collect test losses by ts
                ts_test_losses = defaultdict(list)
                for run in runs:
                    if run["is_success"] and run["final_test_loss"] is not None:
                        ts_test_losses[run["ts"]].append(run["final_test_loss"])
                
                # Compute averages and standard errors
                means = []
                errors = []
                valid_ts = []
                for ts in ts_list:
                    losses = ts_test_losses.get(ts, [])
                    if losses:
                        mean_loss = np.mean(losses)
                        std_loss = np.std(losses) / np.sqrt(len(losses)) if len(losses) > 1 else 0
                        means.append(mean_loss)
                        errors.append(std_loss)
                        valid_ts.append(ts)
                
                if means:
                    # Plot means with error bars
                    x = range(len(valid_ts))
                    ax.errorbar(x, means, yerr=errors, fmt='o-', capsize=5, capthick=2, elinewidth=2)
                    ax.set_xticks(x)
                    ax.set_xticklabels([f"{int(ts[0])}" for ts in valid_ts], rotation=45)
                    ax.set_xlabel('ts (first element)')
                    ax.set_ylabel('Average Final Test Loss')
                    ax.set_title(f'Success: {successful_runs}/{total_runs}')
                    ax.set_ylim(y_limits)  # Set fixed y-scale
                    ax.grid(True)
                else:
                    ax.axis('off')
            else:
                ax.axis('off')
    
    # Add hyperaxis labels for outer and inner learning rates
    for j, outer_lr in enumerate(outer_lrs):
        fig.text(
            (j + 0.5) / len(outer_lrs), 1.01,
            f'Outer LR: {outer_lr:.1e}',
            ha='center', va='bottom', fontsize=10, transform=fig.transFigure
        )
    
    for i, inner_lr in enumerate(inner_lrs):
        fig.text(
            -0.01, (len(inner_lrs) - i - 0.5) / len(inner_lrs),
            f'Inner LR: {inner_lr:.1e}',
            ha='right', va='center', fontsize=10, transform=fig.transFigure
        )
    
    plt.suptitle(f'Average Final Test Loss by ts\n(Group: {group_name}, Optimizer: {optimizer}, Learner: {learner}, Success Threshold: {success_threshold})', fontsize=16)
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    
    # Save plot
    subfolder = f"opt_{sanitize_folder_name(optimizer)}_learner_{sanitize_folder_name(learner)}"
    group_results_dir = os.path.join(results_dir, group_name, subfolder)
    os.makedirs(group_results_dir, exist_ok=True)
    output_file = os.path.join(group_results_dir, 'test_loss_grid.png')
    plt.savefig(output_file, bbox_inches='tight')
    plt.close()
    logger.info(f"Saved test loss grid plot for inner_optimizer={optimizer}, inner_learner={learner} to {output_file}")

# %%
download_results_file = os.path.join(download_dir, f'download_results_{group_name}.pkl')
if not os.path.exists(download_results_file):
    logger.error(f"Download results file not found at {download_results_file}")

# %%
with open(download_results_file, 'rb') as f:
    download_results = pickle.load(f)

# %%
with ThreadPoolExecutor(max_workers=max_process_workers) as executor:
    process_results = list(executor.map(process_run, download_results))
# Out:
# INFO:2025-04-19 22:39:34,394:jax._src.xla_bridge:925: Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# 2025-04-19 22:39:34,394 - INFO - Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# INFO:2025-04-19 22:39:34,396:jax._src.xla_bridge:925: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# 2025-04-19 22:39:34,396 - INFO - Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# 2025-04-19 22:39:34,741 - INFO - Processed run e0fh6y0e: success=False, final_test_loss=None
# 2025-04-19 22:39:34,743 - INFO - Processed run 9ob4c701: success=False, final_test_loss=None
# 2025-04-19 22:39:34,981 - INFO - Processed run isv73zvp: success=True, final_test_loss=0.46704187989234924
# 2025-04-19 22:39:34,981 - INFO - Processed run 79ygnuzq: success=True, final_test_loss=0.4624350368976593
# 2025-04-19 22:39:34,981 - INFO - Processed run gvfaz9pa: success=True, final_test_loss=0.4585985839366913
# 2025-04-19 22:39:34,981 - INFO - Processed run 1nr7lnlj: success=True, final_test_loss=0.4590325653553009
# 2025-04-19 22:39:34,982 - INFO - Processed run 7u6yxcmw: success=True, final_test_loss=0.45910096168518066
# 2025-04-19 22:39:34,982 - INFO - Processed run ixrtrjdn: success=True, final_test_loss=0.46439990401268005
# 2025-04-19 22:39:34,982 - INFO - Processed run di860t9p: success=True, final_test_loss=0.4589385688304901
# 2025-04-19 22:39:34,982 - INFO - Processed run g1mnjrxk: success=True, final_test_loss=0.458822101354599
# 2025-04-19 22:39:34,982 - INFO - Processed run abwe9znm: success=True, final_test_loss=0.46691083908081055
# 2025-04-19 22:39:34,983 - INFO - Processed run 0lfnlsx6: success=True, final_test_loss=0.458763062953949
# 2025-04-19 22:39:35,287 - INFO - Processed run 47pw2620: success=True, final_test_loss=0.4587309956550598
# 2025-04-19 22:39:35,294 - INFO - Processed run rkb2wkqq: success=True, final_test_loss=0.4588877856731415
# 2025-04-19 22:39:35,294 - INFO - Processed run nox9hb1j: success=False, final_test_loss=None
# 2025-04-19 22:39:35,327 - INFO - Processed run vpwxx9oy: success=False, final_test_loss=None
# 2025-04-19 22:39:35,327 - INFO - Processed run qux6k6fn: success=True, final_test_loss=0.4589129686355591
# 2025-04-19 22:39:35,327 - INFO - Processed run a1dwfzhj: success=True, final_test_loss=0.4632369875907898
# 2025-04-19 22:39:35,329 - INFO - Processed run 8ajcy4bp: success=True, final_test_loss=0.45898348093032837
# 2025-04-19 22:39:35,330 - INFO - Processed run mu7o9913: success=True, final_test_loss=0.45899519324302673
# 2025-04-19 22:39:35,330 - INFO - Processed run 7aqll8yn: success=False, final_test_loss=None
# 2025-04-19 22:39:35,331 - INFO - Processed run 81a466nw: success=True, final_test_loss=0.4596650302410126
# 2025-04-19 22:39:35,600 - INFO - Processed run gmyhjbfm: success=False, final_test_loss=None
# 2025-04-19 22:39:35,633 - INFO - Processed run gdbqgpih: success=False, final_test_loss=None
# 2025-04-19 22:39:35,634 - INFO - Processed run cgje2z95: success=False, final_test_loss=None
# 2025-04-19 22:39:35,634 - INFO - Processed run g3uk4dyr: success=True, final_test_loss=0.4590345621109009
# 2025-04-19 22:39:35,635 - INFO - Processed run vizkwwtu: success=True, final_test_loss=0.45901429653167725
# 2025-04-19 22:39:35,635 - INFO - Processed run ad50ahsr: success=True, final_test_loss=0.45940810441970825
# 2025-04-19 22:39:35,636 - INFO - Processed run f91z8rpy: success=True, final_test_loss=0.4659859836101532
# 2025-04-19 22:39:35,636 - INFO - Processed run xm8e7knu: success=True, final_test_loss=0.45889756083488464
# 2025-04-19 22:39:35,636 - INFO - Processed run t1q8vxyb: success=True, final_test_loss=0.4590126872062683
# 2025-04-19 22:39:35,637 - INFO - Processed run gbhe8hpc: success=True, final_test_loss=0.4653502404689789
# 2025-04-19 22:39:35,945 - INFO - Processed run 2o5bpqo7: success=False, final_test_loss=None
# 2025-04-19 22:39:35,953 - INFO - Processed run kw0tgq60: success=False, final_test_loss=None
# 2025-04-19 22:39:35,954 - INFO - Processed run 056wo86k: success=True, final_test_loss=0.4684481918811798
# 2025-04-19 22:39:35,954 - INFO - Processed run 4r0xa0bc: success=True, final_test_loss=0.4607947766780853
# 2025-04-19 22:39:35,954 - INFO - Processed run q1katgcp: success=True, final_test_loss=0.4597172141075134
# 2025-04-19 22:39:35,954 - INFO - Processed run uee02ni5: success=True, final_test_loss=0.4588259160518646
# 2025-04-19 22:39:35,955 - INFO - Processed run 2l9aq1xl: success=True, final_test_loss=0.45906296372413635
# 2025-04-19 22:39:35,955 - INFO - Processed run k5j5h3eu: success=True, final_test_loss=0.45895013213157654
# 2025-04-19 22:39:35,956 - INFO - Processed run lkbaut3u: success=True, final_test_loss=0.4594019055366516
# 2025-04-19 22:39:35,956 - INFO - Processed run u845c31c: success=True, final_test_loss=0.46009519696235657
# 2025-04-19 22:39:36,266 - INFO - Processed run 4ctnd5rh: success=False, final_test_loss=None
# 2025-04-19 22:39:36,274 - INFO - Processed run h679pgkf: success=True, final_test_loss=0.465424120426178
# 2025-04-19 22:39:36,274 - INFO - Processed run 3i8wpl8j: success=False, final_test_loss=None
# 2025-04-19 22:39:36,275 - INFO - Processed run a3hwgrvm: success=False, final_test_loss=None
# 2025-04-19 22:39:36,275 - INFO - Processed run whazai4f: success=True, final_test_loss=0.4592309892177582
# 2025-04-19 22:39:36,275 - INFO - Processed run 5e6h3tyu: success=True, final_test_loss=0.4604065716266632
# 2025-04-19 22:39:36,275 - INFO - Processed run yoyhnx38: success=True, final_test_loss=0.4602898955345154
# 2025-04-19 22:39:36,276 - INFO - Processed run qt2smh8x: success=True, final_test_loss=0.4608372449874878
# 2025-04-19 22:39:36,276 - INFO - Processed run q2axln2p: success=True, final_test_loss=0.4595129191875458
# 2025-04-19 22:39:36,277 - INFO - Processed run vrkf0uaf: success=True, final_test_loss=0.45893967151641846
# 2025-04-19 22:39:36,604 - INFO - Processed run ifzrjsod: success=False, final_test_loss=None
# 2025-04-19 22:39:36,607 - INFO - Processed run ewiey5jb: success=False, final_test_loss=None
# 2025-04-19 22:39:36,608 - INFO - Processed run msrqfd68: success=True, final_test_loss=0.4599660634994507
# 2025-04-19 22:39:36,621 - INFO - Processed run wj5s6x57: success=True, final_test_loss=0.4600088894367218
# 2025-04-19 22:39:36,628 - INFO - Processed run qlq4f9ui: success=True, final_test_loss=0.4590243101119995
# 2025-04-19 22:39:36,628 - INFO - Processed run rrgjqczn: success=True, final_test_loss=0.4682263135910034
# 2025-04-19 22:39:36,631 - INFO - Processed run c9mg8p4h: success=True, final_test_loss=0.47057342529296875
# 2025-04-19 22:39:36,631 - INFO - Processed run ghtx6ez9: success=True, final_test_loss=0.4593489170074463
# 2025-04-19 22:39:36,632 - INFO - Processed run lyvpa395: success=True, final_test_loss=0.45984798669815063
# 2025-04-19 22:39:36,632 - INFO - Processed run h5vnixfe: success=True, final_test_loss=0.45951032638549805
# 2025-04-19 22:39:37,002 - INFO - Processed run ts69gt16: success=False, final_test_loss=None
# 2025-04-19 22:39:37,043 - INFO - Processed run hw0y2xb9: success=True, final_test_loss=0.46034714579582214
# 2025-04-19 22:39:37,046 - INFO - Processed run nd3zv7bm: success=False, final_test_loss=None
# 2025-04-19 22:39:37,065 - INFO - Processed run qh3pco7h: success=True, final_test_loss=0.4592590630054474
# 2025-04-19 22:39:37,079 - INFO - Processed run tszzj0sj: success=False, final_test_loss=None
# 2025-04-19 22:39:37,080 - INFO - Processed run atzr8zp4: success=True, final_test_loss=0.46646541357040405
# 2025-04-19 22:39:37,081 - INFO - Processed run lietfpet: success=True, final_test_loss=0.4591705799102783
# 2025-04-19 22:39:37,081 - INFO - Processed run 0janx5ef: success=True, final_test_loss=0.4592560827732086
# 2025-04-19 22:39:37,082 - INFO - Processed run 30yocccb: success=True, final_test_loss=0.4649279713630676
# 2025-04-19 22:39:37,083 - INFO - Processed run wrov9gsa: success=True, final_test_loss=0.46381399035453796
# 2025-04-19 22:39:37,400 - INFO - Processed run l5m4n7kd: success=False, final_test_loss=None
# 2025-04-19 22:39:37,406 - INFO - Processed run 4o5v25xz: success=True, final_test_loss=0.46147602796554565
# 2025-04-19 22:39:37,407 - INFO - Processed run wjcs5uz8: success=True, final_test_loss=0.46007004380226135
# 2025-04-19 22:39:37,407 - INFO - Processed run 6n51fa0t: success=True, final_test_loss=0.46000319719314575
# 2025-04-19 22:39:37,418 - INFO - Processed run t06yx3z0: success=True, final_test_loss=0.4599534571170807
# 2025-04-19 22:39:37,418 - INFO - Processed run 1y0rt98t: success=True, final_test_loss=0.4599091708660126
# 2025-04-19 22:39:37,418 - INFO - Processed run 9qfsw8jz: success=True, final_test_loss=0.46631884574890137
# 2025-04-19 22:39:37,422 - INFO - Processed run 45czph2y: success=True, final_test_loss=0.4599932134151459
# 2025-04-19 22:39:37,423 - INFO - Processed run au6vcz4w: success=False, final_test_loss=None
# 2025-04-19 22:39:37,423 - INFO - Processed run wv2utbr3: success=True, final_test_loss=0.4607773423194885
# 2025-04-19 22:39:37,752 - INFO - Processed run o2zs7qds: success=True, final_test_loss=0.4644991457462311
# 2025-04-19 22:39:37,760 - INFO - Processed run drixt6gx: success=True, final_test_loss=nan
# 2025-04-19 22:39:37,761 - INFO - Processed run mav94syh: success=True, final_test_loss=0.46068304777145386
# 2025-04-19 22:39:37,762 - INFO - Processed run jop3zgxr: success=True, final_test_loss=0.4680006206035614
# 2025-04-19 22:39:37,762 - INFO - Processed run cy6z9old: success=True, final_test_loss=0.46216580271720886
# 2025-04-19 22:39:37,762 - INFO - Processed run wv5nbvee: success=False, final_test_loss=None
# 2025-04-19 22:39:37,763 - INFO - Processed run bso8df0d: success=True, final_test_loss=0.4677727520465851
# 2025-04-19 22:39:37,764 - INFO - Processed run dokrjbs7: success=True, final_test_loss=0.4608787000179291
# 2025-04-19 22:39:37,764 - INFO - Processed run wemzf0z4: success=True, final_test_loss=0.460358202457428
# 2025-04-19 22:39:37,765 - INFO - Processed run l7obvvp8: success=True, final_test_loss=0.4603249430656433
# 2025-04-19 22:39:38,040 - INFO - Processed run m5wxsagh: success=True, final_test_loss=0.4612886607646942
# 2025-04-19 22:39:38,040 - INFO - Processed run gbdfgcga: success=True, final_test_loss=0.4628223478794098
# 2025-04-19 22:39:38,044 - INFO - Processed run hrq01i21: success=True, final_test_loss=0.4637961685657501
# 2025-04-19 22:39:38,045 - INFO - Processed run 6777t2ip: success=True, final_test_loss=0.4686809480190277
# 2025-04-19 22:39:38,045 - INFO - Processed run y9lay2q5: success=True, final_test_loss=0.4666256308555603
# 2025-04-19 22:39:38,046 - INFO - Processed run dju5yl44: success=True, final_test_loss=0.4611629843711853
# 2025-04-19 22:39:38,052 - INFO - Processed run hppv1wig: success=True, final_test_loss=0.4726586937904358
# 2025-04-19 22:39:38,052 - INFO - Processed run lgtms320: success=True, final_test_loss=0.46024999022483826
# 2025-04-19 22:39:38,061 - INFO - Processed run m12kc689: success=True, final_test_loss=0.46107426285743713
# 2025-04-19 22:39:38,062 - INFO - Processed run dqpftp4b: success=True, final_test_loss=0.4611454904079437
# 2025-04-19 22:39:38,362 - INFO - Processed run 7maf56es: success=True, final_test_loss=0.46925926208496094
# 2025-04-19 22:39:38,364 - INFO - Processed run 3l5l0x8o: success=True, final_test_loss=0.465764582157135
# 2025-04-19 22:39:38,364 - INFO - Processed run bwm3lloy: success=True, final_test_loss=0.4624357223510742
# 2025-04-19 22:39:38,364 - INFO - Processed run btt468ly: success=True, final_test_loss=0.4623355269432068
# 2025-04-19 22:39:38,365 - INFO - Processed run 2u2pmvgg: success=True, final_test_loss=0.46630150079727173
# 2025-04-19 22:39:38,366 - INFO - Processed run z5w6eewo: success=True, final_test_loss=0.4752388000488281
# 2025-04-19 22:39:38,366 - INFO - Processed run 3rm0cztq: success=True, final_test_loss=0.4697767496109009
# 2025-04-19 22:39:38,366 - INFO - Processed run o0vo2ll4: success=True, final_test_loss=0.4683866500854492
# 2025-04-19 22:39:38,367 - INFO - Processed run 71c2m2ds: success=True, final_test_loss=0.4594484269618988
# 2025-04-19 22:39:38,367 - INFO - Processed run 8wxycj56: success=True, final_test_loss=0.46178749203681946
# 2025-04-19 22:39:38,668 - INFO - Processed run uxmxkp3s: success=True, final_test_loss=0.4622986316680908
# 2025-04-19 22:39:38,703 - INFO - Processed run ykoh6gmo: success=True, final_test_loss=0.4639846682548523
# 2025-04-19 22:39:38,703 - INFO - Processed run u3mqorn3: success=False, final_test_loss=None
# 2025-04-19 22:39:38,704 - INFO - Processed run dz6qnxxo: success=True, final_test_loss=0.4610286056995392
# 2025-04-19 22:39:38,704 - INFO - Processed run mqhbm1qw: success=True, final_test_loss=0.4702114164829254
# 2025-04-19 22:39:38,704 - INFO - Processed run wf2jt8l1: success=True, final_test_loss=0.46638792753219604
# 2025-04-19 22:39:38,705 - INFO - Processed run w6wie49c: success=True, final_test_loss=0.46404993534088135
# 2025-04-19 22:39:38,706 - INFO - Processed run rcn7r8y8: success=True, final_test_loss=0.46270447969436646
# 2025-04-19 22:39:38,706 - INFO - Processed run 061dsy27: success=True, final_test_loss=0.4676741063594818
# 2025-04-19 22:39:38,707 - INFO - Processed run v6ulirtf: success=True, final_test_loss=0.46286800503730774
# 2025-04-19 22:39:38,979 - INFO - Processed run fjwr2rai: success=False, final_test_loss=None
# 2025-04-19 22:39:38,981 - INFO - Processed run po369xb9: success=True, final_test_loss=0.46540525555610657
# 2025-04-19 22:39:38,998 - INFO - Processed run hksyqeeq: success=True, final_test_loss=0.4625069797039032
# 2025-04-19 22:39:39,006 - INFO - Processed run 9le5khf1: success=True, final_test_loss=0.4629076421260834
# 2025-04-19 22:39:39,010 - INFO - Processed run a85fth9a: success=True, final_test_loss=0.4647553563117981
# 2025-04-19 22:39:39,011 - INFO - Processed run 6nopgrb6: success=True, final_test_loss=0.4630417227745056
# 2025-04-19 22:39:39,012 - INFO - Processed run 5ytkazjt: success=True, final_test_loss=0.47039783000946045
# 2025-04-19 22:39:39,012 - INFO - Processed run tfbn8oml: success=True, final_test_loss=0.4621823728084564
# 2025-04-19 22:39:39,013 - INFO - Processed run 8x91onl5: success=True, final_test_loss=0.46340399980545044
# 2025-04-19 22:39:39,014 - INFO - Processed run 5yn6cek1: success=True, final_test_loss=0.4698873460292816
# 2025-04-19 22:39:39,215 - INFO - Processed run a8wc5692: success=True, final_test_loss=0.46240657567977905
# 2025-04-19 22:39:39,215 - INFO - Processed run cetws4qh: success=True, final_test_loss=0.4666284918785095
# 2025-04-19 22:39:39,309 - INFO - Processed run it52uuck: success=True, final_test_loss=0.46899622678756714
# 2025-04-19 22:39:39,313 - INFO - Processed run hadamuln: success=False, final_test_loss=None
# 2025-04-19 22:39:39,313 - INFO - Processed run gss7h8n7: success=True, final_test_loss=0.46068283915519714
# 2025-04-19 22:39:39,314 - INFO - Processed run wqz8yltd: success=True, final_test_loss=0.4632255733013153
# 2025-04-19 22:39:39,314 - INFO - Processed run vij2f6y6: success=True, final_test_loss=0.4634878933429718
# 2025-04-19 22:39:39,315 - INFO - Processed run qnvnhetv: success=True, final_test_loss=0.4676457345485687
# 2025-04-19 22:39:39,316 - INFO - Processed run nezr4akp: success=True, final_test_loss=0.46516096591949463
# 2025-04-19 22:39:39,316 - INFO - Processed run qevxbj6q: success=True, final_test_loss=0.4682527184486389
# 2025-04-19 22:39:39,621 - INFO - Processed run tav3lo9c: success=True, final_test_loss=0.46314120292663574
# 2025-04-19 22:39:39,621 - INFO - Processed run 2zvzjk6c: success=True, final_test_loss=0.4681437015533447
# 2025-04-19 22:39:39,622 - INFO - Processed run en9axvg2: success=False, final_test_loss=None
# 2025-04-19 22:39:39,622 - INFO - Processed run 68knjcyq: success=False, final_test_loss=None
# 2025-04-19 22:39:39,623 - INFO - Processed run 4ytthah2: success=True, final_test_loss=0.46384450793266296
# 2025-04-19 22:39:39,624 - INFO - Processed run 8tqg59vj: success=True, final_test_loss=0.46660974621772766
# 2025-04-19 22:39:39,624 - INFO - Processed run xqdn4cbc: success=False, final_test_loss=None
# 2025-04-19 22:39:39,625 - INFO - Processed run sqj35opd: success=True, final_test_loss=0.4685395359992981
# 2025-04-19 22:39:39,625 - INFO - Processed run mi3mndde: success=True, final_test_loss=0.47510722279548645
# 2025-04-19 22:39:39,625 - INFO - Processed run 5h6kr9lv: success=True, final_test_loss=0.46265116333961487
# 2025-04-19 22:39:39,796 - INFO - Processed run di04b57z: success=True, final_test_loss=0.4699121117591858
# 2025-04-19 22:39:39,889 - INFO - Processed run tzpen3t1: success=True, final_test_loss=0.463931143283844
# 2025-04-19 22:39:39,890 - INFO - Processed run lcelin2g: success=False, final_test_loss=None
# 2025-04-19 22:39:39,899 - INFO - Processed run hg2jdjwj: success=False, final_test_loss=None
# 2025-04-19 22:39:39,904 - INFO - Processed run lds7hk4s: success=True, final_test_loss=0.4621823728084564
# 2025-04-19 22:39:39,910 - INFO - Processed run jxobu6mn: success=True, final_test_loss=0.46503159403800964
# 2025-04-19 22:39:39,911 - INFO - Processed run xd900weh: success=True, final_test_loss=0.4675678014755249
# 2025-04-19 22:39:39,918 - INFO - Processed run 9tlns770: success=True, final_test_loss=0.46741223335266113
# 2025-04-19 22:39:39,919 - INFO - Processed run uxt47s98: success=True, final_test_loss=0.4665546417236328
# 2025-04-19 22:39:39,921 - INFO - Processed run w1g8y0gj: success=True, final_test_loss=0.4667893350124359
# 2025-04-19 22:39:40,194 - INFO - Processed run w821xbx9: success=False, final_test_loss=None
# 2025-04-19 22:39:40,201 - INFO - Processed run nlcfh11w: success=False, final_test_loss=None
# 2025-04-19 22:39:40,201 - INFO - Processed run llseyqjy: success=False, final_test_loss=None
# 2025-04-19 22:39:40,201 - INFO - Processed run nw03s4xk: success=True, final_test_loss=0.4637678563594818
# 2025-04-19 22:39:40,201 - INFO - Processed run wpprgvec: success=True, final_test_loss=0.46555447578430176
# 2025-04-19 22:39:40,218 - INFO - Processed run i58ktvk3: success=True, final_test_loss=0.46540960669517517
# 2025-04-19 22:39:40,223 - INFO - Processed run k5kktj54: success=True, final_test_loss=0.47131776809692383
# 2025-04-19 22:39:40,223 - INFO - Processed run zcfcdouc: success=True, final_test_loss=0.46782177686691284
# 2025-04-19 22:39:40,224 - INFO - Processed run t1pfbvj3: success=False, final_test_loss=None
# 2025-04-19 22:39:40,225 - INFO - Processed run gt2y396b: success=True, final_test_loss=0.46691542863845825
# 2025-04-19 22:39:40,468 - INFO - Processed run 44anaab7: success=False, final_test_loss=None
# 2025-04-19 22:39:40,487 - INFO - Processed run hjah0ye3: success=False, final_test_loss=None
# 2025-04-19 22:39:40,492 - INFO - Processed run js8tsq51: success=False, final_test_loss=None
# 2025-04-19 22:39:40,493 - INFO - Processed run 3oaio2ts: success=True, final_test_loss=0.46819666028022766
# 2025-04-19 22:39:40,493 - INFO - Processed run 0q9mmpj9: success=True, final_test_loss=0.4716181457042694
# 2025-04-19 22:39:40,501 - INFO - Processed run v8db8g6p: success=True, final_test_loss=0.4710177481174469
# 2025-04-19 22:39:40,501 - INFO - Processed run m50tt1iv: success=False, final_test_loss=None
# 2025-04-19 22:39:40,516 - INFO - Processed run 7kem0pb0: success=True, final_test_loss=0.4678766429424286
# 2025-04-19 22:39:40,517 - INFO - Processed run 1296y4kj: success=True, final_test_loss=0.46889686584472656
# 2025-04-19 22:39:40,519 - INFO - Processed run cmirlj8b: success=True, final_test_loss=0.4691154658794403
# 2025-04-19 22:39:40,769 - INFO - Processed run q7xoeqc9: success=False, final_test_loss=None
# 2025-04-19 22:39:40,809 - INFO - Processed run z5vbnpuw: success=False, final_test_loss=None
# 2025-04-19 22:39:40,810 - INFO - Processed run zi8awj6a: success=False, final_test_loss=None
# 2025-04-19 22:39:40,812 - INFO - Processed run vwfcfjix: success=True, final_test_loss=0.4717547595500946
# 2025-04-19 22:39:40,849 - INFO - Processed run y40pkdd2: success=False, final_test_loss=None
# 2025-04-19 22:39:40,850 - INFO - Processed run ur0fmuik: success=True, final_test_loss=0.4671374261379242
# 2025-04-19 22:39:40,857 - INFO - Processed run vrxd9pyp: success=False, final_test_loss=None
# 2025-04-19 22:39:40,861 - INFO - Processed run 2fvoph7u: success=False, final_test_loss=None
# 2025-04-19 22:39:40,863 - INFO - Processed run 35751cvw: success=True, final_test_loss=0.4680357277393341
# 2025-04-19 22:39:40,863 - INFO - Processed run w084y4ws: success=True, final_test_loss=0.46717458963394165
# 2025-04-19 22:39:41,143 - INFO - Processed run fe68zpx7: success=True, final_test_loss=0.47196513414382935
# 2025-04-19 22:39:41,152 - INFO - Processed run 0swoawz7: success=True, final_test_loss=0.47106796503067017
# 2025-04-19 22:39:41,166 - INFO - Processed run g9w9zeys: success=False, final_test_loss=None
# 2025-04-19 22:39:41,169 - INFO - Processed run tgcn12ie: success=True, final_test_loss=0.46883177757263184
# 2025-04-19 22:39:41,172 - INFO - Processed run 0ph22ixv: success=True, final_test_loss=0.4714513123035431
# 2025-04-19 22:39:41,198 - INFO - Processed run 7x7voktj: success=True, final_test_loss=0.47143465280532837
# 2025-04-19 22:39:41,206 - INFO - Processed run 4qprvhfl: success=True, final_test_loss=0.47040754556655884
# 2025-04-19 22:39:41,230 - INFO - Processed run f9px2jqd: success=False, final_test_loss=None
# 2025-04-19 22:39:41,230 - INFO - Processed run g70q8ja3: success=False, final_test_loss=None
# 2025-04-19 22:39:41,236 - INFO - Processed run s7jygmxc: success=False, final_test_loss=None
# 2025-04-19 22:39:41,463 - INFO - Processed run 0zh35kzu: success=False, final_test_loss=None
# 2025-04-19 22:39:41,488 - INFO - Processed run ywl7x6vg: success=False, final_test_loss=None
# 2025-04-19 22:39:41,497 - INFO - Processed run vro58aoo: success=False, final_test_loss=None
# 2025-04-19 22:39:41,498 - INFO - Processed run w4hsdvn2: success=False, final_test_loss=None
# 2025-04-19 22:39:41,500 - INFO - Processed run 1b5ia8mw: success=True, final_test_loss=0.4748666286468506
# 2025-04-19 22:39:41,519 - INFO - Processed run bn4f0plr: success=True, final_test_loss=0.4686652719974518
# 2025-04-19 22:39:41,519 - INFO - Processed run ai5658pf: success=True, final_test_loss=0.46996644139289856
# 2025-04-19 22:39:41,529 - INFO - Processed run 6cvdl0yw: success=True, final_test_loss=0.4672330319881439
# 2025-04-19 22:39:41,532 - INFO - Processed run 1c68q1o4: success=False, final_test_loss=None
# 2025-04-19 22:39:41,533 - INFO - Processed run 1dop8nvc: success=False, final_test_loss=None
# 2025-04-19 22:39:41,803 - INFO - Processed run slaziun1: success=False, final_test_loss=None
# 2025-04-19 22:39:41,805 - INFO - Processed run r7sctet4: success=False, final_test_loss=None
# 2025-04-19 22:39:41,814 - INFO - Processed run 9g2qlzeg: success=True, final_test_loss=0.4708985686302185
# 2025-04-19 22:39:41,825 - INFO - Processed run x2lbzr4u: success=False, final_test_loss=None
# 2025-04-19 22:39:41,825 - INFO - Processed run c58i1or9: success=True, final_test_loss=0.4764688014984131
# 2025-04-19 22:39:41,828 - INFO - Processed run 2qhsom4t: success=True, final_test_loss=0.46880868077278137
# 2025-04-19 22:39:41,828 - INFO - Processed run c3da7t17: success=True, final_test_loss=0.4903077483177185
# 2025-04-19 22:39:41,830 - INFO - Processed run heqo8fp6: success=True, final_test_loss=0.48636797070503235
# 2025-04-19 22:39:41,830 - INFO - Processed run e2j9kxq8: success=False, final_test_loss=None
# 2025-04-19 22:39:41,831 - INFO - Processed run 7ax1hpuq: success=True, final_test_loss=0.49025246500968933
# 2025-04-19 22:39:42,130 - INFO - Processed run 8di305fy: success=False, final_test_loss=None
# 2025-04-19 22:39:42,131 - INFO - Processed run pzvki5lv: success=False, final_test_loss=None
# 2025-04-19 22:39:42,154 - INFO - Processed run 75jkc9dy: success=True, final_test_loss=0.4757744073867798
# 2025-04-19 22:39:42,154 - INFO - Processed run fhkb8vn6: success=False, final_test_loss=None
# 2025-04-19 22:39:42,155 - INFO - Processed run 4npwf5bq: success=False, final_test_loss=None
# 2025-04-19 22:39:42,155 - INFO - Processed run 5ld80n4k: success=True, final_test_loss=0.4807675778865814
# 2025-04-19 22:39:42,165 - INFO - Processed run 8rtvrv7s: success=True, final_test_loss=0.4692046344280243
# 2025-04-19 22:39:42,169 - INFO - Processed run 2w53rfi9: success=True, final_test_loss=0.47463205456733704
# 2025-04-19 22:39:42,170 - INFO - Processed run 2xuuxnb6: success=True, final_test_loss=0.47442424297332764
# 2025-04-19 22:39:42,170 - INFO - Processed run 71c1kc7g: success=False, final_test_loss=None
# 2025-04-19 22:39:42,492 - INFO - Processed run bd7pn95x: success=False, final_test_loss=None
# 2025-04-19 22:39:42,499 - INFO - Processed run 888moej9: success=True, final_test_loss=0.47566917538642883
# 2025-04-19 22:39:42,500 - INFO - Processed run 4bxurwat: success=True, final_test_loss=0.4738418757915497
# 2025-04-19 22:39:42,500 - INFO - Processed run zgdygmnw: success=True, final_test_loss=0.4738059341907501
# 2025-04-19 22:39:42,500 - INFO - Processed run pjr6ihd1: success=False, final_test_loss=None
# 2025-04-19 22:39:42,500 - INFO - Processed run y196p2we: success=False, final_test_loss=None
# 2025-04-19 22:39:42,500 - INFO - Processed run ri6atcek: success=False, final_test_loss=None
# 2025-04-19 22:39:42,500 - INFO - Processed run pzcswuvn: success=False, final_test_loss=None
# 2025-04-19 22:39:42,501 - INFO - Processed run 4g19x2t8: success=True, final_test_loss=0.4715650677680969
# 2025-04-19 22:39:42,501 - INFO - Processed run cy87jei6: success=False, final_test_loss=None
# 2025-04-19 22:39:42,727 - INFO - Processed run tew9k9bz: success=False, final_test_loss=None
# 2025-04-19 22:39:42,741 - INFO - Processed run dhmrclkp: success=False, final_test_loss=None
# 2025-04-19 22:39:42,757 - INFO - Processed run qogvg892: success=False, final_test_loss=None
# 2025-04-19 22:39:42,798 - INFO - Processed run d1vv4ur3: success=False, final_test_loss=None
# 2025-04-19 22:39:42,798 - INFO - Processed run 5khil8xt: success=True, final_test_loss=0.4703992009162903
# 2025-04-19 22:39:42,816 - INFO - Processed run e17qe6bo: success=True, final_test_loss=0.48297548294067383
# 2025-04-19 22:39:42,816 - INFO - Processed run 6ev17wmi: success=True, final_test_loss=0.478414922952652
# 2025-04-19 22:39:42,816 - INFO - Processed run qhl1qxsl: success=False, final_test_loss=None
# 2025-04-19 22:39:42,817 - INFO - Processed run yohj0bgx: success=False, final_test_loss=None
# 2025-04-19 22:39:42,817 - INFO - Processed run zsyivy21: success=True, final_test_loss=0.4723696708679199
# 2025-04-19 22:39:43,051 - INFO - Processed run 3fn6o8ju: success=False, final_test_loss=None
# 2025-04-19 22:39:43,085 - INFO - Processed run 35pyvrxz: success=False, final_test_loss=None
# 2025-04-19 22:39:43,101 - INFO - Processed run 1qia2v85: success=False, final_test_loss=None
# 2025-04-19 22:39:43,101 - INFO - Processed run co9pznk7: success=False, final_test_loss=None
# 2025-04-19 22:39:43,101 - INFO - Processed run kvcjbms6: success=True, final_test_loss=0.4765031635761261
# 2025-04-19 22:39:43,101 - INFO - Processed run 46012tm9: success=True, final_test_loss=0.4755100905895233
# 2025-04-19 22:39:43,101 - INFO - Processed run h5v83q8j: success=True, final_test_loss=0.4770067632198334
# 2025-04-19 22:39:43,102 - INFO - Processed run bj8jyz09: success=True, final_test_loss=0.47792741656303406
# 2025-04-19 22:39:43,102 - INFO - Processed run ldyzpaif: success=True, final_test_loss=0.48847082257270813
# 2025-04-19 22:39:43,102 - INFO - Processed run 3jsodcll: success=True, final_test_loss=0.47701799869537354
# 2025-04-19 22:39:43,365 - INFO - Processed run 4gzqezo2: success=False, final_test_loss=None
# 2025-04-19 22:39:43,379 - INFO - Processed run ie9psaxd: success=True, final_test_loss=0.4904058575630188
# 2025-04-19 22:39:43,379 - INFO - Processed run 9b7gs2kv: success=False, final_test_loss=None
# 2025-04-19 22:39:43,379 - INFO - Processed run mpuhe0dd: success=True, final_test_loss=0.47730785608291626
# 2025-04-19 22:39:43,380 - INFO - Processed run u84eqzmz: success=False, final_test_loss=None
# 2025-04-19 22:39:43,412 - INFO - Processed run we810gv3: success=False, final_test_loss=None
# 2025-04-19 22:39:43,416 - INFO - Processed run scwp9qhl: success=False, final_test_loss=None
# 2025-04-19 22:39:43,417 - INFO - Processed run 7ojrg5kc: success=True, final_test_loss=0.47892698645591736
# 2025-04-19 22:39:43,417 - INFO - Processed run j7t3aemj: success=False, final_test_loss=None
# 2025-04-19 22:39:43,418 - INFO - Processed run pyk3zolr: success=True, final_test_loss=0.4769739508628845
# 2025-04-19 22:39:43,670 - INFO - Processed run z55dyg3b: success=False, final_test_loss=None
# 2025-04-19 22:39:43,702 - INFO - Processed run zq5gzp8o: success=False, final_test_loss=None
# 2025-04-19 22:39:43,707 - INFO - Processed run awj35mo6: success=True, final_test_loss=0.47779324650764465
# 2025-04-19 22:39:43,707 - INFO - Processed run o0f8rr4p: success=False, final_test_loss=None
# 2025-04-19 22:39:43,745 - INFO - Processed run xudbsifg: success=True, final_test_loss=0.480882465839386
# 2025-04-19 22:39:43,749 - INFO - Processed run gz0c7y6j: success=True, final_test_loss=0.47756004333496094
# 2025-04-19 22:39:43,750 - INFO - Processed run kjc9ty3x: success=True, final_test_loss=0.4899405539035797
# 2025-04-19 22:39:43,750 - INFO - Processed run zapflor3: success=False, final_test_loss=None
# 2025-04-19 22:39:43,750 - INFO - Processed run lq2ew4zs: success=True, final_test_loss=0.4863337278366089
# 2025-04-19 22:39:43,752 - INFO - Processed run nxs0t11z: success=True, final_test_loss=0.488072007894516
# 2025-04-19 22:39:43,943 - INFO - Processed run 20p3945x: success=True, final_test_loss=0.47377851605415344
# 2025-04-19 22:39:44,024 - INFO - Processed run swr5gjmo: success=False, final_test_loss=None
# 2025-04-19 22:39:44,025 - INFO - Processed run 8zvflixi: success=False, final_test_loss=None
# 2025-04-19 22:39:44,027 - INFO - Processed run g6duowgh: success=False, final_test_loss=None
# 2025-04-19 22:39:44,045 - INFO - Processed run 99r3e5y2: success=False, final_test_loss=None
# 2025-04-19 22:39:44,048 - INFO - Processed run 9kuacf7r: success=False, final_test_loss=None
# 2025-04-19 22:39:44,048 - INFO - Processed run zuy3a5yn: success=False, final_test_loss=None
# 2025-04-19 22:39:44,049 - INFO - Processed run 8fbe4q04: success=True, final_test_loss=0.47623056173324585
# 2025-04-19 22:39:44,049 - INFO - Processed run gxa80sem: success=True, final_test_loss=0.4856886565685272
# 2025-04-19 22:39:44,050 - INFO - Processed run 53ygpa1y: success=True, final_test_loss=0.5565392374992371
# 2025-04-19 22:39:44,219 - INFO - Processed run k9xk267r: success=False, final_test_loss=None
# 2025-04-19 22:39:44,293 - INFO - Processed run ygjcev76: success=False, final_test_loss=None
# 2025-04-19 22:39:44,367 - INFO - Processed run 5etqnfyp: success=False, final_test_loss=None
# 2025-04-19 22:39:44,368 - INFO - Processed run ngwnbhje: success=True, final_test_loss=0.48324817419052124
# 2025-04-19 22:39:44,368 - INFO - Processed run 2eek4e1k: success=False, final_test_loss=None
# 2025-04-19 22:39:44,368 - INFO - Processed run 4uc9u7r2: success=False, final_test_loss=None
# 2025-04-19 22:39:44,385 - INFO - Processed run hjzszvi6: success=True, final_test_loss=0.4761502742767334
# 2025-04-19 22:39:44,397 - INFO - Processed run x02owdkg: success=False, final_test_loss=None
# 2025-04-19 22:39:44,397 - INFO - Processed run xn4hcd2x: success=True, final_test_loss=0.48776260018348694
# 2025-04-19 22:39:44,413 - INFO - Processed run o85mf3u7: success=False, final_test_loss=None
# 2025-04-19 22:39:44,414 - INFO - Processed run okq37oy8: success=False, final_test_loss=None
# 2025-04-19 22:39:44,616 - INFO - Processed run npj3uvok: success=False, final_test_loss=None
# 2025-04-19 22:39:44,629 - INFO - Processed run 9qmgrlcw: success=False, final_test_loss=None
# 2025-04-19 22:39:44,663 - INFO - Processed run mty6usia: success=True, final_test_loss=0.475616455078125
# 2025-04-19 22:39:44,690 - INFO - Processed run f47cxddp: success=False, final_test_loss=None
# 2025-04-19 22:39:44,700 - INFO - Processed run fvsk95zn: success=False, final_test_loss=None
# 2025-04-19 22:39:44,703 - INFO - Processed run jtda0rnm: success=False, final_test_loss=None
# 2025-04-19 22:39:44,704 - INFO - Processed run 7fcz3xp1: success=False, final_test_loss=None
# 2025-04-19 22:39:44,704 - INFO - Processed run 38897x3i: success=False, final_test_loss=None
# 2025-04-19 22:39:44,705 - INFO - Processed run k2vt6q4c: success=False, final_test_loss=None
# 2025-04-19 22:39:44,706 - INFO - Processed run do1ai31m: success=True, final_test_loss=0.4859393537044525
# 2025-04-19 22:39:44,990 - INFO - Processed run wu40qc6p: success=False, final_test_loss=None
# 2025-04-19 22:39:44,991 - INFO - Processed run qd8pz14i: success=False, final_test_loss=None
# 2025-04-19 22:39:44,992 - INFO - Processed run 09dwovib: success=False, final_test_loss=None
# 2025-04-19 22:39:44,993 - INFO - Processed run 6vfcrozw: success=False, final_test_loss=None
# 2025-04-19 22:39:44,993 - INFO - Processed run qeyniq49: success=True, final_test_loss=0.616470456123352
# 2025-04-19 22:39:45,003 - INFO - Processed run xc6r485p: success=False, final_test_loss=None
# 2025-04-19 22:39:45,003 - INFO - Processed run zsu15vu9: success=False, final_test_loss=None
# 2025-04-19 22:39:45,003 - INFO - Processed run vaibn8tp: success=True, final_test_loss=0.5835773348808289
# 2025-04-19 22:39:45,006 - INFO - Processed run zjoeik48: success=False, final_test_loss=None
# 2025-04-19 22:39:45,008 - INFO - Processed run 4orakz5z: success=True, final_test_loss=0.662244439125061
# 2025-04-19 22:39:45,235 - INFO - Processed run 3lcyniy0: success=False, final_test_loss=None
# 2025-04-19 22:39:45,235 - INFO - Processed run 5rz1v33b: success=False, final_test_loss=None
# 2025-04-19 22:39:45,280 - INFO - Processed run 5sdm7war: success=False, final_test_loss=None
# 2025-04-19 22:39:45,290 - INFO - Processed run kef880y3: success=False, final_test_loss=None
# 2025-04-19 22:39:45,294 - INFO - Processed run igk3tgv4: success=False, final_test_loss=None
# 2025-04-19 22:39:45,295 - INFO - Processed run j0ls1ieg: success=True, final_test_loss=0.4840984344482422
# 2025-04-19 22:39:45,295 - INFO - Processed run u0s1qm91: success=False, final_test_loss=None
# 2025-04-19 22:39:45,295 - INFO - Processed run 6jiwye0o: success=False, final_test_loss=None
# 2025-04-19 22:39:45,295 - INFO - Processed run dlh1vzs8: success=False, final_test_loss=None
# 2025-04-19 22:39:45,295 - INFO - Processed run 5lsl8alb: success=False, final_test_loss=None
# 2025-04-19 22:39:45,551 - INFO - Processed run 9cf9lx04: success=False, final_test_loss=None
# 2025-04-19 22:39:45,556 - INFO - Processed run vbqxt0vm: success=False, final_test_loss=None
# 2025-04-19 22:39:45,556 - INFO - Processed run kvy4ag5l: success=False, final_test_loss=None
# 2025-04-19 22:39:45,586 - INFO - Processed run 4ngn1d66: success=False, final_test_loss=None
# 2025-04-19 22:39:45,615 - INFO - Processed run u05r1yad: success=False, final_test_loss=None
# 2025-04-19 22:39:45,615 - INFO - Processed run vaqg25m4: success=True, final_test_loss=0.6623843312263489
# 2025-04-19 22:39:45,620 - INFO - Processed run b668yjij: success=False, final_test_loss=None
# 2025-04-19 22:39:45,620 - INFO - Processed run b77vycvh: success=True, final_test_loss=0.6626266241073608
# 2025-04-19 22:39:45,620 - INFO - Processed run a8rx4xgs: success=False, final_test_loss=None
# 2025-04-19 22:39:45,620 - INFO - Processed run j8tsgkis: success=False, final_test_loss=None
# 2025-04-19 22:39:45,881 - INFO - Processed run jxch0zt6: success=False, final_test_loss=None
# 2025-04-19 22:39:45,913 - INFO - Processed run jd4rfpqa: success=False, final_test_loss=None
# 2025-04-19 22:39:45,922 - INFO - Processed run 17xgs1b4: success=False, final_test_loss=None
# 2025-04-19 22:39:45,927 - INFO - Processed run ze29faw9: success=True, final_test_loss=0.6493381261825562
# 2025-04-19 22:39:45,927 - INFO - Processed run m6n22kru: success=False, final_test_loss=None
# 2025-04-19 22:39:45,937 - INFO - Processed run fgiv1s21: success=False, final_test_loss=None
# 2025-04-19 22:39:45,938 - INFO - Processed run eowah52b: success=False, final_test_loss=None
# 2025-04-19 22:39:45,939 - INFO - Processed run psgzfoou: success=False, final_test_loss=None
# 2025-04-19 22:39:45,939 - INFO - Processed run mq2b9lw1: success=True, final_test_loss=0.662071704864502
# 2025-04-19 22:39:45,939 - INFO - Processed run mgucgvu6: success=False, final_test_loss=None
# 2025-04-19 22:39:46,197 - INFO - Processed run qzsnpxwt: success=False, final_test_loss=None
# 2025-04-19 22:39:46,206 - INFO - Processed run s8pvytxm: success=False, final_test_loss=None
# 2025-04-19 22:39:46,239 - INFO - Processed run zdfsd9qp: success=True, final_test_loss=0.6638128757476807
# 2025-04-19 22:39:46,242 - INFO - Processed run wvrima88: success=False, final_test_loss=None
# 2025-04-19 22:39:46,243 - INFO - Processed run ghw7c9de: success=False, final_test_loss=None
# 2025-04-19 22:39:46,243 - INFO - Processed run gygyhje4: success=False, final_test_loss=None
# 2025-04-19 22:39:46,243 - INFO - Processed run z4o1x3w8: success=True, final_test_loss=0.6627424955368042
# 2025-04-19 22:39:46,243 - INFO - Processed run 4kk6uzg8: success=False, final_test_loss=None
# 2025-04-19 22:39:46,243 - INFO - Processed run wgiceo05: success=True, final_test_loss=0.5845632553100586
# 2025-04-19 22:39:46,244 - INFO - Processed run sj3i70l0: success=False, final_test_loss=None
# 2025-04-19 22:39:46,507 - INFO - Processed run 2lwvkjj6: success=False, final_test_loss=None
# 2025-04-19 22:39:46,511 - INFO - Processed run nchc5fc3: success=False, final_test_loss=None
# 2025-04-19 22:39:46,517 - INFO - Processed run z44s17gw: success=False, final_test_loss=None
# 2025-04-19 22:39:46,521 - INFO - Processed run 4od9qj4r: success=False, final_test_loss=None
# 2025-04-19 22:39:46,522 - INFO - Processed run oua6wlyg: success=True, final_test_loss=0.6626477837562561
# 2025-04-19 22:39:46,522 - INFO - Processed run ijw9497c: success=True, final_test_loss=0.6580711007118225
# 2025-04-19 22:39:46,522 - INFO - Processed run 9djmdaa9: success=False, final_test_loss=None
# 2025-04-19 22:39:46,523 - INFO - Processed run 4hakkrjg: success=True, final_test_loss=0.6640180945396423
# 2025-04-19 22:39:46,523 - INFO - Processed run 0ppie9zo: success=True, final_test_loss=0.6649624705314636
# 2025-04-19 22:39:46,523 - INFO - Processed run 9aeembdw: success=True, final_test_loss=0.6484329104423523
# 2025-04-19 22:39:46,764 - INFO - Processed run xz5315fu: success=False, final_test_loss=None
# 2025-04-19 22:39:46,791 - INFO - Processed run lrsfex1a: success=False, final_test_loss=None
# 2025-04-19 22:39:46,791 - INFO - Processed run z8cl6pkn: success=False, final_test_loss=None
# 2025-04-19 22:39:46,792 - INFO - Processed run u62bup9b: success=False, final_test_loss=None
# 2025-04-19 22:39:46,802 - INFO - Processed run ng5qm58o: success=False, final_test_loss=None
# 2025-04-19 22:39:46,802 - INFO - Processed run upti578d: success=False, final_test_loss=None
# 2025-04-19 22:39:46,811 - INFO - Processed run 25pkz0c9: success=False, final_test_loss=None
# 2025-04-19 22:39:46,811 - INFO - Processed run mpk1e3kj: success=False, final_test_loss=None
# 2025-04-19 22:39:46,813 - INFO - Processed run 2n9nyf1t: success=True, final_test_loss=0.5122560858726501
# 2025-04-19 22:39:46,813 - INFO - Processed run qs667skd: success=False, final_test_loss=None
# 2025-04-19 22:39:47,098 - INFO - Processed run 35o4e92y: success=True, final_test_loss=0.45901253819465637
# 2025-04-19 22:39:47,099 - INFO - Processed run 9i605y7r: success=True, final_test_loss=0.45893603563308716
# 2025-04-19 22:39:47,100 - INFO - Processed run vtgnfly4: success=True, final_test_loss=0.662712037563324
# 2025-04-19 22:39:47,100 - INFO - Processed run conq2p8u: success=True, final_test_loss=0.4588976502418518
# 2025-04-19 22:39:47,100 - INFO - Processed run b7bbpu0q: success=True, final_test_loss=0.45893895626068115
# 2025-04-19 22:39:47,101 - INFO - Processed run fsmm7a75: success=True, final_test_loss=0.45876288414001465
# 2025-04-19 22:39:47,101 - INFO - Processed run 3safuovr: success=True, final_test_loss=0.4662330448627472
# 2025-04-19 22:39:47,101 - INFO - Processed run dke8d4s6: success=True, final_test_loss=0.45899516344070435
# 2025-04-19 22:39:47,102 - INFO - Processed run bf4d7hd4: success=True, final_test_loss=0.4590824544429779
# 2025-04-19 22:39:47,102 - INFO - Processed run 38d2auyk: success=True, final_test_loss=0.45880547165870667
# 2025-04-19 22:39:47,367 - INFO - Processed run navhcwod: success=True, final_test_loss=0.46682605147361755
# 2025-04-19 22:39:47,367 - INFO - Processed run 0ad8ylha: success=True, final_test_loss=0.4605066776275635
# 2025-04-19 22:39:47,367 - INFO - Processed run q3win2es: success=True, final_test_loss=0.45910096168518066
# 2025-04-19 22:39:47,367 - INFO - Processed run n4mh1pro: success=True, final_test_loss=0.458557665348053
# 2025-04-19 22:39:47,377 - INFO - Processed run rsvptxjj: success=True, final_test_loss=0.4590145945549011
# 2025-04-19 22:39:47,377 - INFO - Processed run 3jqbatyx: success=True, final_test_loss=0.4589499831199646
# 2025-04-19 22:39:47,378 - INFO - Processed run ktbcz5h2: success=True, final_test_loss=0.4588877856731415
# 2025-04-19 22:39:47,378 - INFO - Processed run ne5iks7x: success=False, final_test_loss=None
# 2025-04-19 22:39:47,378 - INFO - Processed run an7sehaz: success=True, final_test_loss=0.46707895398139954
# 2025-04-19 22:39:47,380 - INFO - Processed run n99gfrki: success=True, final_test_loss=0.4594080448150635
# 2025-04-19 22:39:47,650 - INFO - Processed run vpqxl5jz: success=False, final_test_loss=None
# 2025-04-19 22:39:47,651 - INFO - Processed run tvfujuk4: success=True, final_test_loss=0.4590325951576233
# 2025-04-19 22:39:47,655 - INFO - Processed run tjj8m003: success=False, final_test_loss=None
# 2025-04-19 22:39:47,662 - INFO - Processed run x30yrf96: success=False, final_test_loss=None
# 2025-04-19 22:39:47,662 - INFO - Processed run 4mfi2hg2: success=True, final_test_loss=0.4589834213256836
# 2025-04-19 22:39:47,662 - INFO - Processed run g2tzz6ez: success=True, final_test_loss=0.45923763513565063
# 2025-04-19 22:39:47,662 - INFO - Processed run rqb37rrd: success=True, final_test_loss=0.4590345025062561
# 2025-04-19 22:39:47,663 - INFO - Processed run 7wucdn56: success=True, final_test_loss=0.4588260054588318
# 2025-04-19 22:39:47,663 - INFO - Processed run ckgpkzrj: success=True, final_test_loss=0.459113210439682
# 2025-04-19 22:39:47,664 - INFO - Processed run dax6cmbd: success=True, final_test_loss=0.4652822017669678
# 2025-04-19 22:39:47,941 - INFO - Processed run pn16kdl2: success=True, final_test_loss=0.4600876271724701
# 2025-04-19 22:39:47,941 - INFO - Processed run hek0zryo: success=False, final_test_loss=None
# 2025-04-19 22:39:47,941 - INFO - Processed run wk71wf9i: success=False, final_test_loss=None
# 2025-04-19 22:39:47,942 - INFO - Processed run 7sxrue8m: success=False, final_test_loss=None
# 2025-04-19 22:39:47,942 - INFO - Processed run jxc4ad93: success=True, final_test_loss=0.45940184593200684
# 2025-04-19 22:39:47,942 - INFO - Processed run eplix6a2: success=False, final_test_loss=None
# 2025-04-19 22:39:47,943 - INFO - Processed run a9hn86mg: success=True, final_test_loss=0.45971664786338806
# 2025-04-19 22:39:47,943 - INFO - Processed run h7hkv35p: success=True, final_test_loss=0.45899638533592224
# 2025-04-19 22:39:47,944 - INFO - Processed run mhmj0z84: success=True, final_test_loss=0.45961254835128784
# 2025-04-19 22:39:47,945 - INFO - Processed run 34mw5fho: success=True, final_test_loss=0.46079373359680176
# 2025-04-19 22:39:48,269 - INFO - Processed run py126wa4: success=True, final_test_loss=0.45906302332878113
# 2025-04-19 22:39:48,270 - INFO - Processed run zd7pkoz4: success=True, final_test_loss=0.46607762575149536
# 2025-04-19 22:39:48,274 - INFO - Processed run vov0tgv1: success=True, final_test_loss=0.46084246039390564
# 2025-04-19 22:39:48,275 - INFO - Processed run x1rigeqi: success=True, final_test_loss=0.4589400887489319
# 2025-04-19 22:39:48,275 - INFO - Processed run u8qxynrn: success=False, final_test_loss=None
# 2025-04-19 22:39:48,276 - INFO - Processed run 9bjpgexi: success=False, final_test_loss=None
# 2025-04-19 22:39:48,277 - INFO - Processed run ggss2r17: success=True, final_test_loss=0.45914021134376526
# 2025-04-19 22:39:48,277 - INFO - Processed run 5hyw7i5t: success=True, final_test_loss=0.45951277017593384
# 2025-04-19 22:39:48,278 - INFO - Processed run hf2vtan6: success=True, final_test_loss=0.4590243399143219
# 2025-04-19 22:39:48,279 - INFO - Processed run 3164bnsk: success=True, final_test_loss=0.46000900864601135
# 2025-04-19 22:39:48,554 - INFO - Processed run rqzwriwb: success=False, final_test_loss=None
# 2025-04-19 22:39:48,574 - INFO - Processed run pe9q1ba9: success=False, final_test_loss=None
# 2025-04-19 22:39:48,576 - INFO - Processed run 2smc6xj4: success=True, final_test_loss=0.46040695905685425
# 2025-04-19 22:39:48,576 - INFO - Processed run lkc5gdzg: success=True, final_test_loss=0.45996585488319397
# 2025-04-19 22:39:48,587 - INFO - Processed run cirg1d3u: success=True, final_test_loss=0.45951029658317566
# 2025-04-19 22:39:48,587 - INFO - Processed run 3kpht8z9: success=True, final_test_loss=0.45984768867492676
# 2025-04-19 22:39:48,587 - INFO - Processed run b1isubp7: success=False, final_test_loss=None
# 2025-04-19 22:39:48,591 - INFO - Processed run pxxjv799: success=True, final_test_loss=0.4689960777759552
# 2025-04-19 22:39:48,592 - INFO - Processed run bm17uijy: success=True, final_test_loss=0.4592589735984802
# 2025-04-19 22:39:48,593 - INFO - Processed run rawzi1o0: success=True, final_test_loss=0.4634983241558075
# 2025-04-19 22:39:48,840 - INFO - Processed run xjk1t91p: success=False, final_test_loss=None
# 2025-04-19 22:39:48,857 - INFO - Processed run 6jmjpig9: success=False, final_test_loss=None
# 2025-04-19 22:39:48,874 - INFO - Processed run 8xu7239n: success=False, final_test_loss=None
# 2025-04-19 22:39:48,882 - INFO - Processed run 3znmp01m: success=True, final_test_loss=0.46034207940101624
# 2025-04-19 22:39:48,882 - INFO - Processed run wkqfmayb: success=True, final_test_loss=0.45934855937957764
# 2025-04-19 22:39:48,885 - INFO - Processed run sc42wwq6: success=True, final_test_loss=0.460777223110199
# 2025-04-19 22:39:48,885 - INFO - Processed run 78egfhrt: success=True, final_test_loss=0.4599566161632538
# 2025-04-19 22:39:48,904 - INFO - Processed run kakwqaqp: success=True, final_test_loss=nan
# 2025-04-19 22:39:48,905 - INFO - Processed run cmwq8g64: success=False, final_test_loss=None
# 2025-04-19 22:39:48,905 - INFO - Processed run l4oguz9l: success=True, final_test_loss=0.45925578474998474
# 2025-04-19 22:39:49,210 - INFO - Processed run u4yz0zlw: success=True, final_test_loss=0.4600716233253479
# 2025-04-19 22:39:49,216 - INFO - Processed run b4u7fpgf: success=True, final_test_loss=0.4664504826068878
# 2025-04-19 22:39:49,216 - INFO - Processed run h7d70hp9: success=True, final_test_loss=0.46466580033302307
# 2025-04-19 22:39:49,216 - INFO - Processed run vib43b0l: success=True, final_test_loss=0.45999622344970703
# 2025-04-19 22:39:49,216 - INFO - Processed run by81vmis: success=True, final_test_loss=0.45990902185440063
# 2025-04-19 22:39:49,217 - INFO - Processed run mersmqke: success=True, final_test_loss=0.4679677188396454
# 2025-04-19 22:39:49,217 - INFO - Processed run qw3a7nek: success=True, final_test_loss=0.4649355411529541
# 2025-04-19 22:39:49,217 - INFO - Processed run k560tvcs: success=True, final_test_loss=0.4592830538749695
# 2025-04-19 22:39:49,219 - INFO - Processed run 7z1xt4ex: success=True, final_test_loss=0.4608789086341858
# 2025-04-19 22:39:49,219 - INFO - Processed run fppbkj3m: success=True, final_test_loss=0.46032488346099854
# 2025-04-19 22:39:49,493 - INFO - Processed run f0ucerru: success=True, final_test_loss=0.4611630141735077
# 2025-04-19 22:39:49,499 - INFO - Processed run j1mxdcbh: success=True, final_test_loss=0.4602496027946472
# 2025-04-19 22:39:49,502 - INFO - Processed run 07x25yys: success=True, final_test_loss=0.462164968252182
# 2025-04-19 22:39:49,502 - INFO - Processed run hwumjp8o: success=True, final_test_loss=0.4606837332248688
# 2025-04-19 22:39:49,502 - INFO - Processed run vbvlngqx: success=True, final_test_loss=0.4633287489414215
# ...
# 2025-04-19 22:44:57,314 - INFO - Processed run 2be5r0i4: success=True, final_test_loss=0.46795839071273804
# 2025-04-19 22:44:57,314 - INFO - Processed run 46ig9q8e: success=True, final_test_loss=0.4845797121524811
# 2025-04-19 22:44:57,315 - INFO - Processed run zprvdsqn: success=True, final_test_loss=0.4666765630245209
# 2025-04-19 22:44:57,316 - INFO - Processed run g3ewge52: success=True, final_test_loss=0.46132558584213257
# 2025-04-19 22:44:57,316 - INFO - Processed run z4x322kw: success=True, final_test_loss=0.6514111757278442
# 2025-04-19 22:44:57,316 - INFO - Processed run 94pjsw8u: success=True, final_test_loss=0.4612976908683777
# 2025-04-19 22:44:57,572 - INFO - Processed run 3y35icvc: success=True, final_test_loss=0.4587629735469818
# 2025-04-19 22:44:57,610 - INFO - Processed run 8mx5yt83: success=True, final_test_loss=0.46133220195770264
# 2025-04-19 22:44:57,617 - INFO - Processed run lcsdb0ju: success=True, final_test_loss=0.4616064727306366
# 2025-04-19 22:44:57,618 - INFO - Processed run zhyojitg: success=True, final_test_loss=0.483399361371994
# 2025-04-19 22:44:57,618 - INFO - Processed run m3xaron8: success=True, final_test_loss=0.4685421884059906
# 2025-04-19 22:44:57,619 - INFO - Processed run krz1jm5l: success=True, final_test_loss=0.6112834215164185
# 2025-04-19 22:44:57,619 - INFO - Processed run hxbcyi1a: success=True, final_test_loss=0.4860982298851013
# 2025-04-19 22:44:57,620 - INFO - Processed run dj23hjql: success=True, final_test_loss=0.6301182508468628
# 2025-04-19 22:44:57,620 - INFO - Processed run 6w3ka0nf: success=True, final_test_loss=0.48369577527046204
# 2025-04-19 22:44:57,621 - INFO - Processed run 1p72sl7e: success=True, final_test_loss=0.45880329608917236
# 2025-04-19 22:44:57,876 - INFO - Processed run jfajgnhp: success=False, final_test_loss=None
# 2025-04-19 22:44:57,891 - INFO - Processed run vcs2gd56: success=True, final_test_loss=0.4760255813598633
# 2025-04-19 22:44:57,891 - INFO - Processed run 5rte9kce: success=False, final_test_loss=None
# 2025-04-19 22:44:57,891 - INFO - Processed run kuipyava: success=True, final_test_loss=0.4698745906352997
# 2025-04-19 22:44:57,919 - INFO - Processed run qjkhavsf: success=True, final_test_loss=0.46898573637008667
# 2025-04-19 22:44:57,919 - INFO - Processed run ief2ew5e: success=True, final_test_loss=0.5630908012390137
# 2025-04-19 22:44:57,920 - INFO - Processed run v0scgdtf: success=True, final_test_loss=0.4618353843688965
# 2025-04-19 22:44:57,921 - INFO - Processed run kz74gz0k: success=True, final_test_loss=0.45887041091918945
# 2025-04-19 22:44:57,922 - INFO - Processed run f22hefbn: success=True, final_test_loss=0.46162304282188416
# 2025-04-19 22:44:57,923 - INFO - Processed run 3mivycez: success=True, final_test_loss=0.47276923060417175
# 2025-04-19 22:44:58,199 - INFO - Processed run 6y75u7at: success=False, final_test_loss=None
# 2025-04-19 22:44:58,206 - INFO - Processed run qxonyqld: success=True, final_test_loss=0.4623430669307709
# 2025-04-19 22:44:58,207 - INFO - Processed run hrpaaxb6: success=True, final_test_loss=0.4760306477546692
# 2025-04-19 22:44:58,208 - INFO - Processed run q8k6usjz: success=True, final_test_loss=0.46204233169555664
# 2025-04-19 22:44:58,208 - INFO - Processed run urubqobb: success=True, final_test_loss=0.5241289734840393
# 2025-04-19 22:44:58,219 - INFO - Processed run cr7c2wjz: success=True, final_test_loss=0.45896413922309875
# 2025-04-19 22:44:58,223 - INFO - Processed run hxxflcmf: success=False, final_test_loss=None
# 2025-04-19 22:44:58,223 - INFO - Processed run 72m73hyy: success=True, final_test_loss=0.46408089995384216
# 2025-04-19 22:44:58,224 - INFO - Processed run b5xuwrcm: success=True, final_test_loss=0.4589514434337616
# 2025-04-19 22:44:58,225 - INFO - Processed run p447m3dr: success=True, final_test_loss=0.46060803532600403
# 2025-04-19 22:44:58,501 - INFO - Processed run phh88en6: success=False, final_test_loss=None
# 2025-04-19 22:44:58,502 - INFO - Processed run 21n5fde7: success=False, final_test_loss=None
# 2025-04-19 22:44:58,503 - INFO - Processed run tayfyhg6: success=True, final_test_loss=0.4822986125946045
# 2025-04-19 22:44:58,504 - INFO - Processed run au6mtx0m: success=True, final_test_loss=0.4671253263950348
# 2025-04-19 22:44:58,504 - INFO - Processed run nk5fczfa: success=True, final_test_loss=0.461140900850296
# 2025-04-19 22:44:58,504 - INFO - Processed run xf2vcht6: success=False, final_test_loss=None
# 2025-04-19 22:44:58,505 - INFO - Processed run kacelg0v: success=True, final_test_loss=0.46114110946655273
# 2025-04-19 22:44:58,505 - INFO - Processed run 90zn6fat: success=True, final_test_loss=0.48241615295410156
# 2025-04-19 22:44:58,506 - INFO - Processed run 5prfipeb: success=True, final_test_loss=0.4945201575756073
# 2025-04-19 22:44:58,506 - INFO - Processed run khvsf6ov: success=True, final_test_loss=0.4611411392688751
# 2025-04-19 22:44:58,718 - INFO - Processed run idfvdw78: success=False, final_test_loss=None
# 2025-04-19 22:44:58,794 - INFO - Processed run knfq6u5e: success=False, final_test_loss=None
# 2025-04-19 22:44:58,795 - INFO - Processed run a4stqm2e: success=True, final_test_loss=0.4611395001411438
# 2025-04-19 22:44:58,795 - INFO - Processed run s4c2ir8t: success=True, final_test_loss=0.46711018681526184
# 2025-04-19 22:44:58,795 - INFO - Processed run vl6nrzuj: success=True, final_test_loss=0.4670841097831726
# 2025-04-19 22:44:58,797 - INFO - Processed run c8314qbz: success=True, final_test_loss=0.4670411944389343
# 2025-04-19 22:44:58,798 - INFO - Processed run 13263gql: success=True, final_test_loss=0.458822101354599
# 2025-04-19 22:44:58,798 - INFO - Processed run ltxsxx3n: success=True, final_test_loss=0.4611377716064453
# 2025-04-19 22:44:58,799 - INFO - Processed run xtvv3tuy: success=True, final_test_loss=0.48326340317726135
# 2025-04-19 22:44:58,799 - INFO - Processed run ym4dkbm5: success=True, final_test_loss=0.4588220715522766
# 2025-04-19 22:44:59,071 - INFO - Processed run uui39bzw: success=True, final_test_loss=0.458822101354599
# 2025-04-19 22:44:59,075 - INFO - Processed run 8w74lfct: success=False, final_test_loss=None
# 2025-04-19 22:44:59,075 - INFO - Processed run qv0gplnj: success=False, final_test_loss=None
# 2025-04-19 22:44:59,083 - INFO - Processed run ffc42y2o: success=True, final_test_loss=0.4588221609592438
# 2025-04-19 22:44:59,090 - INFO - Processed run gpvc9756: success=True, final_test_loss=0.4611360728740692
# 2025-04-19 22:44:59,090 - INFO - Processed run y3czanti: success=False, final_test_loss=None
# 2025-04-19 22:44:59,091 - INFO - Processed run s05wkpii: success=False, final_test_loss=None
# 2025-04-19 22:44:59,091 - INFO - Processed run ddw273ny: success=True, final_test_loss=0.45882225036621094
# 2025-04-19 22:44:59,092 - INFO - Processed run k4bhlig9: success=True, final_test_loss=0.46113401651382446
# 2025-04-19 22:44:59,094 - INFO - Processed run 5qxrjlhc: success=True, final_test_loss=0.4669707417488098
# 2025-04-19 22:44:59,397 - INFO - Processed run 314v5hue: success=False, final_test_loss=None
# 2025-04-19 22:44:59,404 - INFO - Processed run 4gnqqoqj: success=True, final_test_loss=0.46685487031936646
# 2025-04-19 22:44:59,411 - INFO - Processed run tdjoyypf: success=True, final_test_loss=0.4611346125602722
# 2025-04-19 22:44:59,422 - INFO - Processed run qbcbsgf4: success=True, final_test_loss=0.4588223397731781
# 2025-04-19 22:44:59,422 - INFO - Processed run 4i5b05eg: success=False, final_test_loss=None
# 2025-04-19 22:44:59,422 - INFO - Processed run m2ygl4y0: success=True, final_test_loss=0.46114999055862427
# 2025-04-19 22:44:59,423 - INFO - Processed run bveq8g63: success=True, final_test_loss=0.46637314558029175
# 2025-04-19 22:44:59,424 - INFO - Processed run e7eabce2: success=False, final_test_loss=None
# 2025-04-19 22:44:59,425 - INFO - Processed run 23mgghuq: success=True, final_test_loss=0.47036072611808777
# 2025-04-19 22:44:59,426 - INFO - Processed run adit1b6q: success=True, final_test_loss=0.45882248878479004
# 2025-04-19 22:44:59,718 - INFO - Processed run yqheiah7: success=True, final_test_loss=0.4702915847301483
# 2025-04-19 22:44:59,730 - INFO - Processed run ut51ixcd: success=True, final_test_loss=0.46409374475479126
# 2025-04-19 22:44:59,736 - INFO - Processed run 7fj1i52j: success=True, final_test_loss=0.5812394022941589
# 2025-04-19 22:44:59,736 - INFO - Processed run 86qux2o5: success=True, final_test_loss=0.4701808989048004
# 2025-04-19 22:44:59,736 - INFO - Processed run dqtble7x: success=True, final_test_loss=0.4841935336589813
# 2025-04-19 22:44:59,737 - INFO - Processed run oxk4q33m: success=True, final_test_loss=0.5819873213768005
# 2025-04-19 22:44:59,738 - INFO - Processed run vjo0m5pp: success=True, final_test_loss=0.46011990308761597
# 2025-04-19 22:44:59,738 - INFO - Processed run aenc71y9: success=True, final_test_loss=0.4841245114803314
# 2025-04-19 22:44:59,739 - INFO - Processed run l427w2uh: success=True, final_test_loss=0.4641540050506592
# 2025-04-19 22:44:59,739 - INFO - Processed run h2b227hn: success=True, final_test_loss=0.4641313850879669
# 2025-04-19 22:45:00,019 - INFO - Processed run f7hajwlr: success=True, final_test_loss=0.47000300884246826
# 2025-04-19 22:45:00,023 - INFO - Processed run skw29m0a: success=True, final_test_loss=0.5797722935676575
# 2025-04-19 22:45:00,030 - INFO - Processed run 9uiye88w: success=True, final_test_loss=0.4640350341796875
# 2025-04-19 22:45:00,031 - INFO - Processed run fakuryut: success=True, final_test_loss=0.46008172631263733
# 2025-04-19 22:45:00,031 - INFO - Processed run 2h0zdkn3: success=True, final_test_loss=0.4697265028953552
# 2025-04-19 22:45:00,032 - INFO - Processed run 9aoufd8i: success=True, final_test_loss=0.48431965708732605
# 2025-04-19 22:45:00,033 - INFO - Processed run k4ilrq72: success=True, final_test_loss=0.5769970417022705
# 2025-04-19 22:45:00,034 - INFO - Processed run zsrpleb3: success=True, final_test_loss=0.4841512441635132
# 2025-04-19 22:45:00,035 - INFO - Processed run 3fq94ysr: success=True, final_test_loss=0.4639367163181305
# 2025-04-19 22:45:00,035 - INFO - Processed run a8k057ha: success=True, final_test_loss=0.4600543975830078
# 2025-04-19 22:45:00,316 - INFO - Processed run xdbeqk2i: success=True, final_test_loss=0.46323344111442566
# 2025-04-19 22:45:00,324 - INFO - Processed run fy61ge3j: success=True, final_test_loss=0.4635588824748993
# 2025-04-19 22:45:00,325 - INFO - Processed run csc7wikh: success=True, final_test_loss=0.45994627475738525
# 2025-04-19 22:45:00,333 - INFO - Processed run epj128f1: success=True, final_test_loss=0.5571598410606384
# 2025-04-19 22:45:00,346 - INFO - Processed run qivtszny: success=True, final_test_loss=0.484761118888855
# 2025-04-19 22:45:00,346 - INFO - Processed run ten5sw5l: success=True, final_test_loss=0.4600108861923218
# 2025-04-19 22:45:00,347 - INFO - Processed run xq0ad8sc: success=True, final_test_loss=0.46378666162490845
# 2025-04-19 22:45:00,347 - INFO - Processed run 9xoqn1ec: success=True, final_test_loss=0.5691474676132202
# 2025-04-19 22:45:00,349 - INFO - Processed run 4u9yyxl6: success=True, final_test_loss=0.4848392903804779
# 2025-04-19 22:45:00,350 - INFO - Processed run s701qj4z: success=True, final_test_loss=0.468740314245224
# 2025-04-19 22:45:00,635 - INFO - Processed run nqra0nr4: success=False, final_test_loss=None
# 2025-04-19 22:45:00,666 - INFO - Processed run ez5y6wuj: success=True, final_test_loss=0.46912065148353577
# 2025-04-19 22:45:00,693 - INFO - Processed run qpfbhna4: success=True, final_test_loss=0.4680124819278717
# 2025-04-19 22:45:00,694 - INFO - Processed run wywlqhzi: success=True, final_test_loss=0.46797099709510803
# 2025-04-19 22:45:00,695 - INFO - Processed run 2acr0yzw: success=True, final_test_loss=0.6631683707237244
# 2025-04-19 22:45:00,695 - INFO - Processed run n794ddvd: success=True, final_test_loss=0.4739629626274109
# 2025-04-19 22:45:00,695 - INFO - Processed run y6iz8y1v: success=True, final_test_loss=0.4598557949066162
# 2025-04-19 22:45:00,696 - INFO - Processed run zcye0xrm: success=False, final_test_loss=None
# 2025-04-19 22:45:00,698 - INFO - Processed run kbb5jtx7: success=True, final_test_loss=0.4672107696533203
# 2025-04-19 22:45:00,698 - INFO - Processed run up66ubrl: success=True, final_test_loss=0.6553398370742798
# 2025-04-19 22:45:00,951 - INFO - Processed run u3fbve3j: success=True, final_test_loss=0.4842630624771118
# 2025-04-19 22:45:00,957 - INFO - Processed run 1j86yl1m: success=True, final_test_loss=0.4779996871948242
# 2025-04-19 22:45:00,963 - INFO - Processed run zzmm6459: success=True, final_test_loss=0.6521737575531006
# 2025-04-19 22:45:00,992 - INFO - Processed run vtwilmdm: success=True, final_test_loss=0.47115692496299744
# 2025-04-19 22:45:00,993 - INFO - Processed run dahix4un: success=True, final_test_loss=0.633898138999939
# 2025-04-19 22:45:00,993 - INFO - Processed run is78wxe8: success=True, final_test_loss=0.6631090641021729
# 2025-04-19 22:45:00,994 - INFO - Processed run hxhihwfj: success=True, final_test_loss=0.6631413698196411
# 2025-04-19 22:45:00,995 - INFO - Processed run ulsi5lce: success=True, final_test_loss=0.4725615680217743
# 2025-04-19 22:45:00,995 - INFO - Processed run m4sbrrvx: success=True, final_test_loss=0.46533167362213135
# 2025-04-19 22:45:00,995 - INFO - Processed run tr85l07x: success=True, final_test_loss=0.4811039865016937
# 2025-04-19 22:45:01,277 - INFO - Processed run 04z874ow: success=True, final_test_loss=0.4683728814125061
# 2025-04-19 22:45:01,287 - INFO - Processed run 2mb3bbjp: success=True, final_test_loss=0.6630514860153198
# 2025-04-19 22:45:01,296 - INFO - Processed run ojakdp0q: success=True, final_test_loss=0.46976351737976074
# 2025-04-19 22:45:01,298 - INFO - Processed run 50yremkq: success=True, final_test_loss=0.6630762815475464
# 2025-04-19 22:45:01,298 - INFO - Processed run uivzceej: success=True, final_test_loss=0.4640429615974426
# 2025-04-19 22:45:01,298 - INFO - Processed run bad3m3cw: success=True, final_test_loss=0.4974764585494995
# 2025-04-19 22:45:01,299 - INFO - Processed run 1bsvn6ev: success=True, final_test_loss=0.47516170144081116
# 2025-04-19 22:45:01,299 - INFO - Processed run gia9vlet: success=True, final_test_loss=0.5318679809570312
# 2025-04-19 22:45:01,300 - INFO - Processed run vqicf2j1: success=True, final_test_loss=0.46290120482444763
# 2025-04-19 22:45:01,300 - INFO - Processed run efia2z37: success=True, final_test_loss=0.5104219317436218
# 2025-04-19 22:45:01,594 - INFO - Processed run lrfci59k: success=True, final_test_loss=0.4669957458972931
# 2025-04-19 22:45:01,594 - INFO - Processed run gb7hiq6h: success=True, final_test_loss=0.47055622935295105
# 2025-04-19 22:45:01,595 - INFO - Processed run ixam9it3: success=True, final_test_loss=0.6630384922027588
# 2025-04-19 22:45:01,596 - INFO - Processed run j0cefh9j: success=True, final_test_loss=0.4644680619239807
# 2025-04-19 22:45:01,597 - INFO - Processed run twveqaxr: success=True, final_test_loss=0.4656774699687958
# 2025-04-19 22:45:01,603 - INFO - Processed run ym1obq3y: success=True, final_test_loss=0.4611967206001282
# 2025-04-19 22:45:01,609 - INFO - Processed run jcwlndmy: success=True, final_test_loss=0.4924021363258362
# 2025-04-19 22:45:01,609 - INFO - Processed run 5zca1m6u: success=True, final_test_loss=0.4899142384529114
# 2025-04-19 22:45:01,610 - INFO - Processed run hh1aehfq: success=True, final_test_loss=0.46195268630981445
# 2025-04-19 22:45:01,611 - INFO - Processed run d9wsqv6z: success=True, final_test_loss=0.6630432605743408
# 2025-04-19 22:45:01,795 - INFO - Processed run fuwg3o1y: success=True, final_test_loss=0.6631028652191162
# 2025-04-19 22:45:01,810 - INFO - Processed run q4o31y4g: success=True, final_test_loss=0.4837583005428314
# 2025-04-19 22:45:01,811 - INFO - Processed run tpszpd3f: success=True, final_test_loss=0.4669494926929474
# 2025-04-19 22:45:01,812 - INFO - Processed run i29r1lnk: success=True, final_test_loss=0.6630637645721436
# 2025-04-19 22:45:01,812 - INFO - Processed run h7jsahft: success=True, final_test_loss=0.46860799193382263
# 2025-04-19 22:45:01,813 - INFO - Processed run 1ok6vdyk: success=True, final_test_loss=0.46340417861938477

# %%
all_runs_data = []
for result in process_results:
    if result["status"] == "success" and result["data"] and result["data"]["is_success"]:
        all_runs_data.append(result["data"])

# %%
optimizer_learner_pairs = set()
for run in all_runs_data:
    optimizer = run["config"].get("inner_optimizer", "unknown")
    learner = run["config"].get("inner_learner", "unknown")
    optimizer_learner_pairs.add((optimizer, learner))

# %%
y_limits = (0.45, 0.7)  # Fixed y-axis limits for all subplots
# Generate grid plots for each optimizer and learner combination
for optimizer, learner in sorted(optimizer_learner_pairs):
    logger.info(f"Generating grid plot for inner_optimizer={optimizer}, inner_learner={learner}")
    create_grid_plot(all_runs_data, optimizer, learner, group_name)
# Out:
# 2025-04-19 22:57:57,540 - INFO - Generating grid plot for inner_optimizer=sgd, inner_learner=rtrl
# 2025-04-19 22:58:02,981 - INFO - Saved test loss grid plot for inner_optimizer=sgd, inner_learner=rtrl to /scratch/results/mlr_search-1_aa9c06652fb34624bebe972b1fe7292f/opt_sgd_learner_rtrl/test_loss_grid.png
# 2025-04-19 22:58:02,983 - INFO - Generating grid plot for inner_optimizer=sgd_normalized, inner_learner=rtrl
# 2025-04-19 22:58:07,615 - INFO - Saved test loss grid plot for inner_optimizer=sgd_normalized, inner_learner=rtrl to /scratch/results/mlr_search-1_aa9c06652fb34624bebe972b1fe7292f/opt_sgd_normalized_learner_rtrl/test_loss_grid.png
